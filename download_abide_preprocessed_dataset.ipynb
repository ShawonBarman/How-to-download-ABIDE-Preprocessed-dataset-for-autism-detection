# %%
# Out:
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050004_rois_cc200.1D
# 0.113% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050005_rois_cc200.1D
# 0.226% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050006_rois_cc200.1D
# 0.339% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050007_rois_cc200.1D
# 0.452% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050008_rois_cc200.1D
# 0.566% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050009_rois_cc200.1D
# 0.679% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050010_rois_cc200.1D
# 0.792% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050011_rois_cc200.1D
# 0.905% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050012_rois_cc200.1D
# 1.018% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050014_rois_cc200.1D
# 1.131% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050015_rois_cc200.1D
# 1.244% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050016_rois_cc200.1D
# 1.357% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050020_rois_cc200.1D
# 1.471% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050022_rois_cc200.1D
# 1.584% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050023_rois_cc200.1D
# 1.697% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050024_rois_cc200.1D
# 1.810% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050025_rois_cc200.1D
# 1.923% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050027_rois_cc200.1D
# 2.036% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050029_rois_cc200.1D
# 2.149% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050030_rois_cc200.1D
# 2.262% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050031_rois_cc200.1D
# 2.376% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050032_rois_cc200.1D
# 2.489% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050033_rois_cc200.1D
# 2.602% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050034_rois_cc200.1D
# 2.715% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050035_rois_cc200.1D
# 2.828% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050036_rois_cc200.1D
# 2.941% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050037_rois_cc200.1D
# 3.054% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050038_rois_cc200.1D
# 3.167% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050040_rois_cc200.1D
# 3.281% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050041_rois_cc200.1D
# 3.394% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050042_rois_cc200.1D
# 3.507% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050044_rois_cc200.1D
# 3.620% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050045_rois_cc200.1D
# 3.733% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050046_rois_cc200.1D
# 3.846% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050047_rois_cc200.1D
# 3.959% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050048_rois_cc200.1D
# 4.072% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050050_rois_cc200.1D
# 4.186% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050051_rois_cc200.1D
# 4.299% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050052_rois_cc200.1D
# 4.412% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050055_rois_cc200.1D
# 4.525% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050056_rois_cc200.1D
# 4.638% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050057_rois_cc200.1D
# 4.751% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050058_rois_cc200.1D
# 4.864% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050059_rois_cc200.1D
# 4.977% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Pitt_0050060_rois_cc200.1D
# 5.090% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050102_rois_cc200.1D
# 5.204% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050104_rois_cc200.1D
# 5.317% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050105_rois_cc200.1D
# 5.430% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050107_rois_cc200.1D
# 5.543% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050111_rois_cc200.1D
# 5.656% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050112_rois_cc200.1D
# 5.769% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050113_rois_cc200.1D
# 5.882% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050114_rois_cc200.1D
# 5.995% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050115_rois_cc200.1D
# 6.109% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050116_rois_cc200.1D
# 6.222% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050117_rois_cc200.1D
# 6.335% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050118_rois_cc200.1D
# 6.448% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050119_rois_cc200.1D
# 6.561% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050121_rois_cc200.1D
# 6.674% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050122_rois_cc200.1D
# 6.787% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050125_rois_cc200.1D
# 6.900% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050127_rois_cc200.1D
# 7.014% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050128_rois_cc200.1D
# 7.127% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050129_rois_cc200.1D
# 7.240% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050130_rois_cc200.1D
# 7.353% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050131_rois_cc200.1D
# 7.466% percent complete
# Retrieving: preprocessed_dataset\Outputs/cpac/filt_global/rois_cc200/Olin_0050132_rois_cc200.1D

# %%
# Main collect and download function
def collect_and_download(derivative, pipeline, strategy, out_dir, diagnosis):
    import os
    import urllib.request as request

    # Init variables
    mean_fd_thresh = 0.2
    s3_prefix = 'https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative'
    s3_pheno_path = '/'.join([s3_prefix, 'Phenotypic_V1_0b_preprocessed1.csv'])

    derivative = derivative.lower()
    pipeline = pipeline.lower()
    strategy = strategy.lower()

    # Check derivative for extension
    if 'roi' in derivative:
        extension = '.1D'
    else:
        extension = '.nii.gz'

    if not os.path.exists(out_dir):
        print('Could not find {0}, creating now...'.format(out_dir))
        os.makedirs(out_dir)

    s3_pheno_file = request.urlopen(s3_pheno_path)
    pheno_list = s3_pheno_file.readlines()

    header = pheno_list[0].decode().split(',')
    try:
        site_idx = header.index('SITE_ID')
        file_idx = header.index('FILE_ID')
        age_idx = header.index('AGE_AT_SCAN')
        sex_idx = header.index('SEX')
        dx_idx = header.index('DX_GROUP')
        mean_fd_idx = header.index('func_mean_fd')
    except Exception as exc:
        err_msg = 'Unable to extract header information from the pheno file...'
        raise Exception(err_msg)

    s3_paths = []
    for pheno_row in pheno_list[1:]:
        cs_row = pheno_row.decode().split(',')

        try:
            row_file_id = cs_row[file_idx]
            row_site = cs_row[site_idx]
            row_age = float(cs_row[age_idx])
            row_sex = cs_row[sex_idx]
            row_dx = cs_row[dx_idx]
            row_mean_fd = float(cs_row[mean_fd_idx])
        except Exception as e:
            continue

        if row_file_id == 'no_filename':
            continue
        if row_mean_fd >= mean_fd_thresh:
            continue

        if (diagnosis == 'asd' and row_dx != '1') or (diagnosis == 'tdc' and row_dx != '2'):
            continue

        filename = row_file_id + '_' + derivative + extension
        s3_path = '/'.join([s3_prefix, 'Outputs', pipeline, strategy, derivative, filename])
        s3_paths.append(s3_path)

    total_num_files = len(s3_paths)
    for path_idx, s3_path in enumerate(s3_paths):
        rel_path = s3_path.lstrip(s3_prefix)
        download_file = os.path.join(out_dir, rel_path)
        download_dir = os.path.dirname(download_file)
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)
        try:
            if not os.path.exists(download_file):
                print('Retrieving: {0}'.format(download_file))
                request.urlretrieve(s3_path, download_file)
                print('{0:.3f}% percent complete'.format(100*(float(path_idx+1)/total_num_files)))
            else:
                print('File {0} already exists, skipping...'.format(download_file))
        except Exception as exc:
            print('There was a problem downloading {0}.\n Check input arguments and try again.'.format(s3_path))

    print('Done!')

# pipelines = ["ccs", "cpac", "dparsf", "niak"]
# strategies = ["filt_global", "filt_noglobal", "nofilt_global", "nofilt_noglobal"]
# derivatives = ["alff", "degree_binarize", "degree_weighted", "dual_regression", "eigenvector_binarize", "eigenvector_weighted", "falff", "func_mask", "func_mean", "func_preproc", "lfcd", "reho", "rois_aal", "rois_cc200", "rois_cc400", "rois_dosenbach160", "rois_ez", "rois_ho", "rois_tt", "vmhc"]
# extensions = ["1D", "nii.gz"]
    
# Variables to specify download settings (modify these values as needed)
desired_derivative = 'rois_cc200'  # Derivative of interest (e.g. 'reho')
desired_pipeline = 'cpac'     # Pipeline used to preprocess the data (e.g. 'cpac')    
desired_strategy = 'filt_global'  # Noise-removal strategy used during preprocessing
download_data_dir = 'preprocessed_dataset'  # Path to local folder to download files to
desired_diagnosis = 'both'  # 'asd', 'tdc', or 'both' corresponding to the diagnosis of the participants for whom data should be downloaded

# Call the collect and download routine
collect_and_download(desired_derivative, desired_pipeline, desired_strategy, download_data_dir, desired_diagnosis)

# %% [markdown]
# ## Another way but you need to connect csv file so that get file id

# %%
import os
import requests

# Base URL for the dataset
base_url = "https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs"

# Function to construct the download URL
def construct_url(pipeline, strategy, derivative, file_id, ext):
    return f"{base_url}/{pipeline}/{strategy}/{derivative}/{file_id}_{derivative}.{ext}"

# Function to download a file from a given URL
def download_file(url, destination):
    response = requests.get(url, stream=True)
    with open(destination, "wb") as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

# Display options and get user choice
def get_user_choice(options):
    for i, option in enumerate(options, start=1):
        print(f"{i}. {option}")
    choice = input("Enter your choice: ")
    return choice

# Available options
pipelines = ["ccs", "cpac", "dparsf", "niak"]
strategies = ["filt_global", "filt_noglobal", "nofilt_global", "nofilt_noglobal"]
derivatives = ["alff", "degree_binarize", "degree_weighted", "dual_regression", "eigenvector_binarize", "eigenvector_weighted", "falff", "func_mask", "func_mean", "func_preproc", "lfcd", "reho", "rois_aal", "rois_cc200", "rois_cc400", "rois_dosenbach160", "rois_ez", "rois_ho", "rois_tt", "vmhc"]
extensions = ["1D", "nii.gz"]

# Get user choices
pipeline_choice = int(get_user_choice(pipelines))
strategy_choice = int(get_user_choice(strategies))
derivative_choice = int(get_user_choice(derivatives))
extension_choice = int(get_user_choice(extensions))

file_id = input("Enter FILE_ID value: ")

# Get the chosen options
chosen_pipeline = pipelines[pipeline_choice - 1]
chosen_strategy = strategies[strategy_choice - 1]
chosen_derivative = derivatives[derivative_choice - 1]
chosen_extension = extensions[extension_choice - 1]

# Construct the download URL
url = construct_url(chosen_pipeline, chosen_strategy, chosen_derivative, file_id, chosen_extension)

# Specify the destination directory
destination_dir = "downloaded_data"
os.makedirs(destination_dir, exist_ok=True)

# Specify the destination file path
destination_file = os.path.join(destination_dir, f"{file_id}_{chosen_derivative}.{chosen_extension}")

# Download the file
download_file(url, destination_file)

print("File downloaded successfully!")
